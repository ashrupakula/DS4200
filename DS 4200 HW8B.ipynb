# %%
import altair as alt
import pandas as pd

df1 = pd.read_excel('/Users/ashwinrupakula/Desktop/Fall 2022/DS 4200/table3.xlsx')
df2 = pd.read_excel('/Users/ashwinrupakula/Desktop/Fall 2022/DS 4200/table5.xlsx')
df3 = pd.read_excel('/Users/ashwinrupakula/Desktop/Fall 2022/DS 4200/table6.xlsx')

df1
# Out:
#        Land cover types              Location      Area
# 0   NWI marine wetlands                Mystic   1298.80
# 1            Salt marsh                Mystic     46.80
# 2    Freshwater Wetland                Mystic     94.30
# 3            City parks                Mystic   1214.70
# 4                 Beach                Mystic     35.25
# 5            Freshwater                Mystic    786.24
# 6            Oyster bed                Mystic      0.00
# 7               Estuary                Mystic     86.48
# 8            Tidal flat                Mystic      6.68
# 9                Forest                Mystic   4574.30
# 10   Grassland/Openland                Mystic    491.03
# 11        Core habitats                Mystic   1822.92
# 12       Coastal waters                Mystic   5985.33
# 13  NWI marine wetlands  Charles and neponset    671.41
# 14           Salt marsh  Charles and neponset    108.44
# 15   Freshwater Wetland  Charles and neponset     40.80
# ...

# %%
alt.Chart(df1, title = 'Land cover areas (acres) at MHHW by watershed').mark_bar().encode(
    x='Land cover types',
    y='Area',
    color='Land cover types',
    column='Location'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df2, title = 'High and low of Annual value of ecosystem services').mark_bar().encode(
    x='Land cover types',
    y='Value',
    color='Land cover types',
    column='Level'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df3, title = 'High and low of Annual value of ecosystem services with and without cleanup').mark_bar().encode(
    x='Cleanup status',
    y='Value',
    color='Cleanup status',
    column='Level'
)
# Out:
# alt.Chart(...)
